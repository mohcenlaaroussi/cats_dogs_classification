# %% [markdown]
# <a href="https://colab.research.google.com/github/mohcenlaaroussi/cats_dogs_classification/blob/develop/cats_dogs_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
from sys import getsizeof
import os
from PIL import Image,ImageOps
from PIL import UnidentifiedImageError

# %%
! pip install kaggle

! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle datasets download -d mohcenlaaroussi/catsdogs
# Out:
# ...
#  99% 771M/775M [00:07<00:00, 82.8MB/s]
# 100% 775M/775M [00:07<00:00, 106MB/s]

# %%
# !unzip catsdogs.zip -d catsdogs
#!rm glasses-or-no-glasses.zip
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: catsdogs/CatsDogs/Dogs/5499.jpg
#   inflating: catsdogs/CatsDogs/Dogs/55.jpg
#   inflating: catsdogs/CatsDogs/Dogs/550.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5500.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5501.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5502.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5503.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5504.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5505.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5506.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5507.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5508.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5509.jpg
#   inflating: catsdogs/CatsDogs/Dogs/551.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5510.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5511.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5512.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5513.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5514.jpg
#   inflating: catsdogs/CatsDogs/Dogs/5515.jpg
# ...

# %%
path = "./catsdogs/CatsDogs/Cats/10107.jpg"

img_color = cv2.imread(path,1)
img_grayscale = cv2.imread(path,0)
#img_unchanged = cv2.imread('rosebud-6006985_1280.jpg',-1)

# %%
for i in range(9):
    plt.subplot(330 + 1 + i)

# %%
plt.imshow(cv2.cvtColor(img_grayscale, cv2.COLOR_BGR2RGB))

#plt.axis("off")
plt.show()

# %%
#plt.axis("off")
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
#plt.figure(figsize=(2,2))
plt.show()

# %%
from PIL import Image
p= "./catsdogs/CatsDogs/Cats/"
l = ["9565.jpg",
"140.jpg",
"9171.jpg",
"666.jpg",
"7978.jpg",
"936.jpg",
"9778.jpg",
"2663.jpg",
"3491.jpg",
"10501.jpg",
"8470.jpg",
"10820.jpg",
"4833.jpg",
"850.jpg",
"5553.jpg",
"7968.jpg",
"11935.jpg",
"11210.jpg",
"11874.jpg",
"3300.jpg",
"10125.jpg",
"10404.jpg",
"11565.jpg",
"660.jpg"]
for name in l:
  try:
    img = Image.open(p+name)    # Open image as PIL image object
    print(img)
  except UnidentifiedImageError:
    print('IMAGE NOT DAMAGED: '+name)
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=250x187 at 0x7F3DCA9AA4F0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=253x265 at 0x7F3DCA987CA0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=145x39 at 0x7F3DCA9AA4F0>
# IMAGE NOT DAMAGED: 666.jpg
# <PIL.GifImagePlugin.GifImageFile image mode=P size=213x280 at 0x7F3DCA987CA0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=219x233 at 0x7F3DCA9AA4F0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=408x342 at 0x7F3DCA987CA0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=194x83 at 0x7F3DCA9AA4F0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=259x346 at 0x7F3DCA987CA0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=400x299 at 0x7F3DCA9AA4F0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=75x80 at 0x7F3DCA9AA0A0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=288x282 at 0x7F3DCA987A30>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=85x95 at 0x7F3DCA9AA0A0>
# ...

# %%
im = Image.open(path)
im
im2 = ImageOps.grayscale(im)
im.size
rsizeArr = np.asarray(im2)  # Get array back
rsizeArr.shape
# Out:
# (86, 86)

# %%
from matplotlib.image import imread
image = imread(path)
plt.imshow(image)
#plt.figure(figsize=(2,2))
plt.show()

# %%
path = "./catsdogs/CatsDogs/Cats/10107.jpg"

img_color = cv2.imread(path,1)
#img_color.shape
print(img_color)
print(path)
# Out:
# [[[196 239 242]
#   [197 240 243]
#   [198 241 244]
#   ...
#   [ 84  35  25]
#   [ 87  36  26]
#   [ 88  37  27]]
#
#  [[197 240 243]
#   [197 240 243]
#   [198 241 244]
#   ...
#   [ 85  36  26]
#   [ 88  37  27]
#   [ 89  38  28]]
#
#  [[198 241 244]
#   [198 241 244]
#   [198 241 244]
#   ...
#   [ 86  37  29]
#   [ 89  37  30]
#   [ 89  37  30]]
#
#  ...
#
#  [[171 196 206]
#   [172 197 207]
#   [172 199 209]
#   ...
#   [ 95  99 110]
#   [ 95  99 110]
#   [ 95  99 110]]
#
#  [[167 192 202]
#   [169 194 204]
#   [169 196 206]
#   ...
#   [ 96 101 110]
#   [ 96 101 110]
#   [ 97 102 111]]
#
#  [[165 190 200]
#   [167 192 202]
#   [168 195 205]
#   ...
#   [ 97 102 111]
#   [ 97 102 111]
#   [ 98 103 112]]]
# ./catsdogs/CatsDogs/Cats/10107.jpg

# %%
img_grayscale.shape
# Out:
# (397, 312)

# %%
img_color[0][0]
# Out:
# array([50, 50, 62], dtype=uint8)

# %%
img_grayscale[0][0]
# Out:
# 54

# %%
image_small_size = cv2.resize(img_color, (110, 110))
image_bigger = cv2.resize(img_color, (640, 640))

# %%
plt.imshow(cv2.cvtColor(image_small_size, cv2.COLOR_BGR2RGB))
#plt.figure(figsize=(2,2))
plt.show()

# %%
plt.imshow(cv2.cvtColor(image_bigger, cv2.COLOR_BGR2RGB))
#plt.figure(figsize=(2,2))
plt.show()

# %%
array1 = array(img_color)

# %%
array1

# %%
array1 = np.array(img_color)
size1 = getsizeof(array1)
print(array1)
  
array2 = array1.flatten()
size2 = getsizeof(array2)
print(array2)
  
print(f"Size of Multidimensional Image : {size1}")
print(f"Size of Flattened Image : {size2}")
difference = size1 - size2
print(difference)

# %%
array1.shape
# Out:
# (415, 500, 3)

# %%
array2.shape
# Out:
# (622500,)

# %%
array1 = np.array(img_grayscale)
size1 = getsizeof(array1)
print(array1)
  
array2 = array1.flatten()
size2 = getsizeof(array2)
print(array2)
  
print(f"Size of Multidimensional Image : {size1}")
print(f"Size of Flattened Image : {size2}")
difference = size1 - size2
print(difference)

# %%
array1.shape
# Out:
# (415, 500)

# %%
array2.shape
# Out:
# (207500,)

# %%
os.listdir(path)
# Out:
# ['Cats', 'Dogs']

# %%
from os import walk

f = []
for (dirpath, dirnames, filenames) in os.walk(path):
    f.extend(filenames)
    break

# %%
dirpath, dirnames, filenames = os.walk(path)

# %%
for (root,dirs,files) in os.walk(path, topdown=True):
    print (root)
    print (dirs)
    print (files)
    print ('--------------------------------')
# Out:
# ./catsdogs/CatsDogs
# ['Cats', 'Dogs']
# []
# --------------------------------
# ./catsdogs/CatsDogs/Cats
# []
# ...

# %%
path = "./catsdogs/CatsDogs/Cats"

len(os.listdir(path))
# Out:
# 12500

# %% [markdown]
# ## Distribuzione dimensioni immagini

# %%
img = cv2.imread('./catsdogs/CatsDogs/Cats/6590.jpg',1)

# %%
img.shape
# Out:
# (332, 500, 3)

# %%
hights = []
weights = []

for (root,dirs,files) in os.walk(path, topdown=True):
  if len(files) > 0:
    fnames = list(fname for fname in os.listdir(path) if fname.endswith('.jpg'))

    batchsize = 500
    l_index, r_index = 0, batchsize
    batch = fnames[l_index:r_index]

    while batch:

        for i in batch:
          #print(root+'/'+i)
          #img = cv2.imread(root+'/'+i,1)
          try:
            img = Image.open(root+'/'+i)    # Open image as PIL image object
            hights.append(img.size[0])
            weights.append(img.size[1])
            #print(root+'/'+i)
          except UnidentifiedImageError:
            print('IMAGE DAMAGED: '+i)

        l_index, r_index = r_index, r_index + batchsize
        batch = fnames[l_index:r_index]
# Out:
# IMAGE DAMAGED: 666.jpg

# %%
hights
# Out:
# [500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  320,
#  336,
#  300,
#  240,
#  308,
#  500,
#  500,
#  500,
#  500,
#  450,
#  500,
#  350,
#  216,
#  350,
#  429,
#  408,
#  500,
#  325,
#  500,
#  480,
#  150,
#  500,
#  500,
#  500,
#  260,
#  500,
#  500,
#  375,
#  404,
#  360,
#  109,
#  446,
#  400,
#  500,
#  480,
#  500,
#  500,
#  200,
#  230,
#  500,
#  500,
#  360,
#  367,
#  500,
#  500,
#  334,
#  448,
#  320,
#  276,
#  500,
#  320,
#  375,
#  286,
#  500,
#  500,
#  448,
#  500,
#  500,
#  320,
#  500,
#  500,
#  150,
#  372,
#  320,
#  500,
#  500,
#  500,
#  402,
#  500,
#  190,
#  375,
#  500,
#  443,
#  350,
#  500,
#  300,
#  345,
#  297,
#  500,
#  202,
#  202,
#  500,
#  240,
#  500,
#  138,
#  500,
#  500,
#  362,
#  500,
#  500,
#  202,
#  499,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  420,
#  500,
#  275,
#  423,
#  250,
#  500,
#  110,
#  400,
#  500,
#  320,
#  500,
#  461,
#  310,
#  500,
#  395,
#  300,
#  500,
#  500,
# ...

# %%
plt.hist(hights)
plt.show()

# %%
plt.hist(weights)
plt.show()

# %% [markdown]
# ##dataset

# %%
def create_dataset(path):
  labels = []
  images = []

  fnames = list(fname for fname in os.listdir(path) if fname.endswith('.jpg'))

  batchsize = 500
  l_index, r_index = 0, batchsize
  batch = fnames[l_index:r_index]

  while batch:

      for i in batch:
          #import_function(i) 
          print(i)
      l_index, r_index = r_index, r_index + batchsize
      batch = fnames[l_index:r_index]
  return labels,images

# %%
labels = []
images = []

fnames = list(fname for fname in os.listdir(path) if fname.endswith('.jpg'))

batchsize = 500
l_index, r_index = 0, batchsize
batch = fnames[l_index:r_index]

while batch:

    for i in batch:
        print(cv2.imread(i,1))
        print(i)
    l_index, r_index = r_index, r_index + batchsize
    batch = fnames[l_index:r_index]
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 3154.jpg
# None
# 10219.jpg
# None
# 2300.jpg
# None
# 12279.jpg
# None
# 8849.jpg
# None
# 3830.jpg
# None
# 4493.jpg
# None
# 11708.jpg
# None
# 12073.jpg
# None
# 4999.jpg
# None
# 294.jpg
# None
# 4538.jpg
# None
# 11283.jpg
# None
# 3665.jpg
# None
# 12192.jpg
# None
# 7839.jpg
# None
# 7296.jpg
# None
# 4312.jpg
# None
# 3460.jpg
# None
# 9434.jpg
# None
# 3521.jpg
# None
# 4631.jpg
# None
# 1001.jpg
# None
# 11210.jpg
# None
# 3930.jpg
# None
# 3280.jpg
# None
# 9303.jpg
# None
# 9415.jpg
# None
# 9695.jpg
# None
# 4720.jpg
# None
# 8114.jpg
# None
# 5429.jpg
# None
# 12117.jpg
# None
# 11540.jpg
# None
# 5338.jpg
# None
# 7091.jpg
# None
# 5843.jpg
# None
# 6313.jpg
# None
# 9410.jpg
# None
# 4121.jpg
# None
# 12482.jpg
# None
# 4076.jpg
# None
# 5791.jpg
# None
# 2747.jpg
# None
# 3399.jpg
# None
# 3866.jpg
# None
# 3523.jpg
# None
# 11622.jpg
# None
# 9024.jpg
# None
# 3895.jpg
# None
# 160.jpg
# None
# 9663.jpg
# None
# ...
